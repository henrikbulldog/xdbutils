# %%
# %pip install install git+https://github.com/henrikbulldog/xdbutils.git
# Out:
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Collecting git+https://github.com/henrikbulldog/xdbutils.git
#   Cloning https://github.com/henrikbulldog/xdbutils.git to /tmp/pip-req-build-5s_16fm8
#   Running command git clone --filter=blob:none --quiet https://github.com/henrikbulldog/xdbutils.git /tmp/pip-req-build-5s_16fm8
#   Resolved https://github.com/henrikbulldog/xdbutils.git to commit 5e4d826adaf34ee857ba9250372af39724dad78d
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting install
#   Downloading install-1.3.5-py3-none-any.whl (3.2 kB)
# Collecting pyspark
#   Downloading pyspark-3.4.1.tar.gz (310.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.8/310.8 MB 1.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting py4j==0.10.9.7
#   Downloading py4j-0.10.9.7-py2.py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.5/200.5 kB 11.7 MB/s eta 0:00:00
# Building wheels for collected packages: xdbutils, pyspark
#   Building wheel for xdbutils (setup.py): started
#   Building wheel for xdbutils (setup.py): finished with status 'done'
#   Created wheel for xdbutils: filename=xdbutils-0.0.1-py3-none-any.whl size=15006 sha256=53b5b76c155f9b5179a70a7e3b8f05fe9f101ba5e902c5aef9b37903d662b6e2
#   Stored in directory: /tmp/pip-ephem-wheel-cache-33zx5sj6/wheels/1a/6a/3e/44dcde429c3ae21d23f89d6515608f65a63756dd3d7a19a8fb
#   Building wheel for pyspark (setup.py): started
#   Building wheel for pyspark (setup.py): finished with status 'done'
#   Created wheel for pyspark: filename=pyspark-3.4.1-py2.py3-none-any.whl size=311285397 sha256=00abf6912f7c4068b285295214f23bea99ef6b7042509b6555f042826708b44d
#   Stored in directory: /root/.cache/pip/wheels/0d/77/a3/ff2f74cc9ab41f8f594dabf0579c2a7c6de920d584206e0834
# Successfully built xdbutils pyspark
# Installing collected packages: py4j, pyspark, install, xdbutils
# Successfully installed install-1.3.5 py4j-0.10.9.7 pyspark-3.4.1 xdbutils-0.0.1
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.

# %%
from xdbutils import XDBUtils

xdbutils = XDBUtils(spark, dbutils)

pipeline = xdbutils.create_dlt_batch_pipeline(
  source_system="eds",
  entity="co2emis",
  catalog="testing_dlt",
  tags={
    "data_owner": "Henrik Thomsen",
    "cost_center": "123456",
    "documentation": "https://github.com/henrikbulldog/xdbutils"
  },
  databricks_token=dbutils.secrets().get(scope="<scope>", key="<secret>")
)

# %%
pipeline.raw_to_bronze(
  raw_base_path="dbfs:/FileStore/datalakehouse/raw",
  raw_format="json",
  expectations={
    "Valid dataset": "dataset = 'CO2Emis'",
    "Valid data": "records IS NOT NULL AND array_size(records) > 1",
    }
)
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>bronze_co2emis</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>dataset</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>records</td>
#    <td>array&lt;struct&lt;CO2Emission:double,Minutes5DK:string,Minutes5UTC:string,PriceArea:string&gt;&gt;</td>
# </tr>
#
# <tr>
#    <td>total</td>
#    <td>bigint</td>
# </tr>
#
# <tr>
#    <td>_rescued_data</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>_ingest_time</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>_quarantined</td>
#    <td>boolean</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=6470790689526092#joblist/pipelines/create?initialSource=%2FUsers%2Fhenrik.thomsen%40helen.fi%2FDLT%2Feds%2Fco2emis%2Fdlt_eds_co2emis&redirectNotebookId=1091846230940469">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %%
from pyspark.sql.functions import explode, col, lit

pipeline.bronze_to_silver(
  parse=lambda df: (
    df
    .withColumn("record", explode("records"))
    .select(
      col("record.CO2Emission").alias("value"),
      col("record.Minutes5UTC").cast("timestamp").alias("timestamp"),
      col("record.PriceArea").alias("price_area"),
      )
    ),
  expectations={
    "valid_timestamp": "timestamp IS NOT NULL",
    "valid_value": "value IS NOT NULL"
    }
  )
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>silver_co2emis</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>value</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>timestamp</td>
#    <td>timestamp</td>
# </tr>
#
# <tr>
#    <td>price_area</td>
#    <td>string</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=6470790689526092#joblist/pipelines/create?initialSource=%2FUsers%2Fhenrik.thomsen%40helen.fi%2FDLT%2Feds%2Fco2emis%2Fdlt_eds_co2emis&redirectNotebookId=1091846230940469">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %%
pipeline.silver_to_gold(
  name="top_10",
  parse=lambda df: (
    df
      .where(col("price_area") == lit("DK1"))
      .orderBy(col("value").desc())
      .limit(10)
      .select("value", "timestamp")
  )
)
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>gold_co2emis_top_10</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>value</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>timestamp</td>
#    <td>timestamp</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=6470790689526092#joblist/pipelines/create?initialSource=%2FUsers%2Fhenrik.thomsen%40helen.fi%2FDLT%2Feds%2Fco2emis%2Fdlt_eds_co2emis&redirectNotebookId=1091846230940469">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>
